# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
url = "https://www.naukri.com/data-analyst-jobs?k=data%20analyst"

# %%
df = pd.DataFrame(columns=['Title','Company','Ratings','Reviews','Experience','Salary','Location','Job_Post_History','URL'])

# %%
page = requests.get(url)
page.text
# Out:
# '<!DOCTYPE html> <html lang="en"> <head> <meta http-equiv="X-UA-Compatible" content="IE=Edge" /> <meta name="viewport" content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> <link rel="dns-prefetch preconnect" href="//static.naukimg.com"> <link rel="dns-prefetch preconnect" href="//img.naukimg.com"> <link rel="dns-prefetch preconnect" href="//logs.naukri.com"> <link rel="dns-prefetch preconnect" href="//lg.naukri.com"> <link rel="dns-prefetch" href="https://www.googletagmanager.com" /> <base href="//www.naukri.com" /> <link rel="manifest" href="./manifest.json"> <link rel="preload" as="style" href="//static.naukimg.com/s/7/109/c/main.17ae2b27.min.css"/> <link rel="preload" as="script" href="//static.naukimg.com/s/7/109/j/main.59640394.min.js"> <script>\n        window.ipAddress = "www.naukri.com";\n        window.DEBUG = true;\n        window.appId = 135;\n                    var isCrawler = false;\n                            var ucBrowser = false;\n            </script>   <style type="text/css"> .splScrn{ height: 100%; } body{margin:0} .nkIcon { width: 19rem; height:19rem; margin: auto; position: relative; padding-top: 95px; } .nk-text { font-size: 40px; margin-bottom: 60px; text-align: center; font-weight: 700; color:#999; font-family:arial } #circleG { width: 9rem; margin: auto } .circleG { background-color: #2DABE2; float: left; height: 14px; margin: 5px; width: 14px; animation-name: bounce_circleG; -o-animation-name: bounce_circleG; -ms-animation-name: bounce_circleG; -webkit-animation-name: bounce_circleG; -moz-animation-name: bounce_circleG; animation-duration: 1.8s; -o-animation-duration: 1.8s; -ms-animation-duration: 1.8s; -webkit-animation-duration: 1.8s; -moz-animation-duration: 1.8s; animation-iteration-count: infinite; -o-animation-iteration-count: infinite; -ms-animation-iteration-count: infinite; -webkit-animation-iteration-count: infinite; -moz-animation-iteration-count: infinite; animation-direction: normal; -o-animation-direction: normal; -ms-animation-direction: normal; -webkit-animation-direction: normal; -moz-animation-direction: normal; border-radius: 50%; -o-border-radius: 50%; -ms-border-radius: 50%; -webkit-border-radius: 50%; -moz-border-radius: 50% } #root, body, html { height: 100% } #circleG_1 { animation-delay: .45s; -o-animation-delay: .45s; -ms-animation-delay: .45s; -webkit-animation-delay: .45s; -moz-animation-delay: .45s } #circleG_2 { animation-delay: .65s; -o-animation-delay: .65s; -ms-animation-delay: .65s; -webkit-animation-delay: .65s; -moz-animation-delay: .65s } #circleG_3 { animation-delay: .85s; -o-animation-delay: .85s; -ms-animation-delay: .85s; -webkit-animation-delay: .85s; -moz-animation-delay: .85s } #circleG_4 { animation-delay: 1.05s; -o-animation-delay: 1.05s; -ms-animation-delay: 1.05s; -webkit-animation-delay: 1.05s; -moz-animation-delay: 1.05s } #circleG_5 { animation-delay: 1.25s; -o-animation-delay: 1.25s; -ms-animation-delay: 1.25s; -webkit-animation-delay: 1.25s; -moz-animation-delay: 1.25s } @keyframes bounce_circleG { 50% { width: 10px; height: 10px; margin: 7px; background-color: rgba(12, 109, 182, 0) } } </style> </head> <body>  <noscript> <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NX744H"height="0" width="0" style="display:none;visibility:hidden"></iframe> </noscript>  <div id="root"> <div class="splScrn"> <div class="row top"> <div class="nkIcon"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 315 315"><style type="text/css"> .st0{fill:#2DABE2;} .st1{fill:#0C6DB6;} .st2{fill:#EC2227;} .st3{fill:#444444;} .st4{fill-rule:evenodd;clip-rule:evenodd;fill:#EC2227;} .st5{fill-rule:evenodd;clip-rule:evenodd;fill:#0C6DB6;} </style><path class="st0" d="M0 200.8h10v4.6c1.5-1.9 3-3.2 4.5-4 1.5-0.8 3.4-1.2 5.6-1.2 3 0 5.3 0.9 7 2.7 1.7 1.8 2.5 4.5 2.5 8.2v17.8H18.8v-15.4c0-1.8-0.3-3-1-3.7 -0.7-0.7-1.6-1.1-2.7-1.1 -1.3 0-2.4 0.5-3.2 1.5 -0.8 1-1.2 2.8-1.2 5.3v13.4H0V200.8z"/><path class="st0" d="M45.8  ...

# %%
for param in range(1,100):
    
    driver = webdriver.Chrome("C://Users//Victor//Desktop//chromedriver_win32//chromedriver.exe")
    driver.get(url)

    time.sleep(2)

    soup = BeautifulSoup(driver.page_source,'html5lib')

    # print(soup.prettify())

    driver.close()

    results = soup.find(class_='list')
    job_elems = results.find_all('article',class_='jobTuple bgWhite br4 mb-8')

    for job_elem in job_elems:

        # URL to apply for the job     
        URL = job_elem.find('a',class_='title fw500 ellipsis').get('href')
    #     print(URL.strip())

        # Post Title
        Title = job_elem.find('a',class_='title fw500 ellipsis')

        # Company Name
        Company = job_elem.find('a',class_='subTitle ellipsis fleft')

        # Ratings
        rating_span = job_elem.find('span',class_='starRating fleft dot')
        if rating_span is None:
            continue
        else:
            Ratings = rating_span.text

        # Reviews Counts
        Review_span = job_elem.find('a',class_='reviewsCount ml-5 fleft blue-text')
        if Review_span is None:
            continue
        else:
            Reviews = Review_span.text

        # Years of experience Required
        Exp = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi experience')
        Exp_span = Exp.find('span',class_='ellipsis fleft fs12 lh16')
        if Exp_span is None:
            continue
        else:
            Experience = Exp_span.text

        # Salary offered for the job
        Sal = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi salary')
        Sal_span = Sal.find('span',class_='ellipsis fleft fs12 lh16')
        if Sal_span is None:
            continue
        else:
            Salary = Sal_span.text

        # Location for the job post
        Loc = job_elem.find('li',class_='fleft grey-text br2 placeHolderLi location')
        Loc_exp = Loc.find('span',class_='ellipsis fleft fs12 lh16')
        if Loc_exp is None:
            continue
        else:
            Location = Loc_exp.text

        # Number of days since job posted
        Hist = job_elem.find("div",["type br2 fleft grey","type br2 fleft green"])
        Post_Hist = Hist.find('span',class_='fleft fw500')
        if Post_Hist is None:
            continue
        else:
            Post_History = Post_Hist.text
        
    #   Appending data to the DataFrame 
        df=df.append({'URL':URL,'Title':Title.text,'Company':Company.text,'Ratings':Ratings,'Reviews':Reviews,'Experience':Experience,'Salary':Salary,'Location':Location,'Job_Post_History':Post_History},ignore_index = True)
# Out:
# C:\Users\Victor\AppData\Local\Temp/ipykernel_21764/2173948457.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C://Users//Victor//Desktop//chromedriver_win32//chromedriver.exe")

# %%
df.shape
# Out:
# (1683, 9)

# %%
df.head(23)
# Out:
#                                                 Title  \
# 0                              Associate Data Analyst
# 1                     Sr Domain Expert -Data Analysts
# 2           Financial Business Analyst / Data Analyst
# 3                                 Senior Data Analyst
# 4                              Senior Data Analyst II
# 5                              Senior Data Analyst II
# 6                                     Data Analyst II
# 7                         Blockchain AML Data Analyst
# 8                     Senior Data Analyst - Logistics
# 9                              Associate Data Analyst
# 10                                Senior Data Analyst
# 11                    Business Analyst / Data Analyst
# 12                          Consultant - Data Analyst
# 13                                       Data Analyst
# 14                                People Data Analyst
# 15                                       Data Analyst
# 16  Hiring Freshers - Data Research Analyst - Mana...
# 17                             Associate Data Analyst
# 18                    Sr Domain Expert -Data Analysts
# 19          Financial Business Analyst / Data Analyst
# 20                                Senior Data Analyst
# 21                             Senior Data Analyst II
# 22                             Senior Data Analyst II
#
#                              Company Ratings         Reviews Experience  \
# 0           Urjanet Energy Solutions     3.8    (64 Reviews)    0-3 Yrs
# 1                            Siemens     4.2  (2780 Reviews)   0-10 Yrs
# 2                           Cotiviti     4.0   (179 Reviews)    1-6 Yrs
# 3                         LatentView     4.0    (58 Reviews)    2-6 Yrs
# 4                           Flipkart     4.2  (8802 Reviews)    2-4 Yrs
# 5                           Flipkart     4.2  (8802 Reviews)    3-6 Yrs
# 6                             Cerner     3.9   (618 Reviews)   6-10 Yrs
# 7                             PayPal     4.3   (262 Reviews)    3-7 Yrs
# 8                              Gojek     4.1    (12 Reviews)   4-10 Yrs
# 9           Urjanet Energy Solutions     3.8    (64 Reviews)    0-1 Yrs
# 10                          Flipkart     4.2  (8802 Reviews)    4-6 Yrs
# 11                    DC Consultants     3.7     (5 Reviews)    3-5 Yrs
# 12                          Flipkart     4.2  (8802 Reviews)    1-3 Yrs
# 13  Zetwerk Manufacturing Businesses     4.1    (93 Reviews)    1-3 Yrs
# 14                           Walmart     4.2  (9932 Reviews)   4-10 Yrs
# 15                         Pine Labs     4.1   (482 Reviews)    4-8 Yrs
# 16                       Morningstar     4.4   (316 Reviews)    0-2 Yrs
# 17          Urjanet Energy Solutions     3.8    (64 Reviews)    0-3 Yrs
# 18                           Siemens     4.2  (2780 Reviews)   0-10 Yrs
# 19                          Cotiviti     4.0   (179 Reviews)    1-6 Yrs
# 20                        LatentView     4.0    (58 Reviews)    2-6 Yrs
# 21                          Flipkart     4.2  (8802 Reviews)    2-4 Yrs
# 22                          Flipkart     4.2  (8802 Reviews)    3-6 Yrs
#
#                        Salary                      Location Job_Post_History  \
# 0               Not disclosed                       Chennai        1 Day Ago
# 1               Not disclosed           Bangalore/Bengaluru       9 Days Ago
# 2               Not disclosed                          Pune        1 Day Ago
# 3               Not disclosed  Chennai, Bangalore/Bengaluru       5 Days Ago
# 4               Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 5               Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 6               Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 7               Not disclosed                       Chennai        1 Day Ago
# 8               Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 9               Not disclosed                       Chennai       8 Days Ago
# 10              Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 11              Not disclosed                          Pune        1 Day Ago
# 12              Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 13              Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 14              Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 15  10,00,000 - 15,00,000 PA.                   Delhi / NCR        1 Day Ago
# 16    3,00,000 - 4,75,000 PA.      Mumbai(Sector 30A Vashi)       6 Days Ago
# 17              Not disclosed                       Chennai        1 Day Ago
# 18              Not disclosed           Bangalore/Bengaluru       9 Days Ago
# 19              Not disclosed                          Pune        1 Day Ago
# 20              Not disclosed  Chennai, Bangalore/Bengaluru       5 Days Ago
# 21              Not disclosed           Bangalore/Bengaluru        1 Day Ago
# 22              Not disclosed           Bangalore/Bengaluru        1 Day Ago
#
#                                                   URL
# 0   https://www.naukri.com/job-listings-associate-...
# 1   https://www.naukri.com/job-listings-sr-domain-...
# 2   https://www.naukri.com/job-listings-financial-...
# 3   https://www.naukri.com/job-listings-senior-dat...
# 4   https://www.naukri.com/job-listings-senior-dat...
# 5   https://www.naukri.com/job-listings-senior-dat...
# 6   https://www.naukri.com/job-listings-data-analy...
# 7   https://www.naukri.com/job-listings-blockchain...
# 8   https://www.naukri.com/job-listings-senior-dat...
# 9   https://www.naukri.com/job-listings-associate-...
# 10  https://www.naukri.com/job-listings-senior-dat...
# 11  https://www.naukri.com/job-listings-business-a...
# 12  https://www.naukri.com/job-listings-consultant...
# 13  https://www.naukri.com/job-listings-data-analy...
# 14  https://www.naukri.com/job-listings-people-dat...
# 15  https://www.naukri.com/job-listings-data-analy...
# 16  https://www.naukri.com/job-listings-hiring-fre...
# 17  https://www.naukri.com/job-listings-associate-...
# 18  https://www.naukri.com/job-listings-sr-domain-...
# 19  https://www.naukri.com/job-listings-financial-...
# 20  https://www.naukri.com/job-listings-senior-dat...
# 21  https://www.naukri.com/job-listings-senior-dat...
# 22  https://www.naukri.com/job-listings-senior-dat...

# %%
df.to_csv('file1.csv')
